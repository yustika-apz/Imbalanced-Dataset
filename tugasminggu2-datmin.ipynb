# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

df = pd.read_csv('../input/covid19-in-india/covid_19_india.csv')
df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
Tripura = df[df['State/UnionTerritory'] == 'Tripura']
Tripura
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 735      736  2020-04-07  6:00 PM              Tripura
# 766      767  2020-04-08  5:00 PM              Tripura
# 797      798  2020-04-09  5:00 PM              Tripura
# 828      829  2020-04-10  5:00 PM              Tripura
# 859      860  2020-04-11  5:00 PM              Tripura
# ...      ...         ...      ...                  ...
# 17962  17963  2021-08-07  8:00 AM              Tripura
# 17998  17999  2021-08-08  8:00 AM              Tripura
# 18034  18035  2021-08-09  8:00 AM              Tripura
# 18070  18071  2021-08-10  8:00 AM              Tripura
# 18106  18107  2021-08-11  8:00 AM              Tripura
#
#       ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 735                         -                        -      0       0
# 766                         -                        -      0       0
# 797                         -                        -      0       0
# ...

# %%
kasus = Tripura[Tripura['Confirmed']> 0]
kasus
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 735      736  2020-04-07  6:00 PM              Tripura
# 766      767  2020-04-08  5:00 PM              Tripura
# 797      798  2020-04-09  5:00 PM              Tripura
# 828      829  2020-04-10  5:00 PM              Tripura
# 859      860  2020-04-11  5:00 PM              Tripura
# ...      ...         ...      ...                  ...
# 17962  17963  2021-08-07  8:00 AM              Tripura
# 17998  17999  2021-08-08  8:00 AM              Tripura
# 18034  18035  2021-08-09  8:00 AM              Tripura
# 18070  18071  2021-08-10  8:00 AM              Tripura
# 18106  18107  2021-08-11  8:00 AM              Tripura
#
#       ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 735                         -                        -      0       0
# 766                         -                        -      0       0
# 797                         -                        -      0       0
# ...

# %%
plt.plot(kasus['Date'] , kasus['Confirmed'])
plt.title('Kasus Covid di Tritura India 2020-2021')
plt.xlabel('Date')
plt.ylabel('Jumlah Pasien Terkonfirmasi Terdampak Covid')
plt.show()

# %%
kasusbaru = kasus[kasus.Date >='2021-01-01']
kasusbaru
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 10114  10115  2021-01-01  8:00 AM              Tripura
# 10150  10151  2021-01-02  8:00 AM              Tripura
# 10186  10187  2021-01-03  8:00 AM              Tripura
# 10222  10223  2021-01-04  8:00 AM              Tripura
# 10258  10259  2021-01-05  8:00 AM              Tripura
# ...      ...         ...      ...                  ...
# 17962  17963  2021-08-07  8:00 AM              Tripura
# 17998  17999  2021-08-08  8:00 AM              Tripura
# 18034  18035  2021-08-09  8:00 AM              Tripura
# 18070  18071  2021-08-10  8:00 AM              Tripura
# 18106  18107  2021-08-11  8:00 AM              Tripura
#
#       ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 10114                       -                        -  32779     385
# 10150                       -                        -  32795     385
# 10186                       -                        -  32809     385
# ...

# %%
plt.plot(kasusbaru.Date , kasusbaru.Confirmed)
plt.plot(kasusbaru.Date , kasusbaru.Cured)
plt.plot(kasusbaru.Date , kasusbaru.Deaths)
plt.legend(['Jumlah Pasien Terkonfirmasi', 'Jumlah Pasien yang Sembuh', 'Jumlah Pasien yang Meninggal'])
plt.title('Jumlah Pasien Covid di Tritura India Tahun 2021')
plt.xlabel('Date')
plt.show()

# %%
#kasusConfirmed = kasus[kasus.Confirmed >=0]
import seaborn as sns
India = df[df['Date'] >= '2021-01-01']
India
# Out:
#          Sno        Date     Time         State/UnionTerritory  \
# 10082  10083  2021-01-01  8:00 AM               Andhra Pradesh
# 10083  10084  2021-01-01  8:00 AM  Andaman and Nicobar Islands
# 10084  10085  2021-01-01  8:00 AM            Arunachal Pradesh
# 10085  10086  2021-01-01  8:00 AM                        Assam
# 10086  10087  2021-01-01  8:00 AM                        Bihar
# ...      ...         ...      ...                          ...
# 18105  18106  2021-08-11  8:00 AM                    Telangana
# 18106  18107  2021-08-11  8:00 AM                      Tripura
# 18107  18108  2021-08-11  8:00 AM                  Uttarakhand
# 18108  18109  2021-08-11  8:00 AM                Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM                  West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 10082                       -                        -   871916    7108
# ...

# %%
sns.displot(India['Confirmed'])
plt.title('Jumlah Pasien Terkonfirmasi Covid di India 2021')
plt.show()

# %%
sns.jointplot(x=India['Deaths'], y=India['Cured'] , data=df, kind='kde')
plt.show()
